# %%
import numpy as np
import pandas as pd
import seaborn as sns
pd.set_option('display.max_rows',2000)
pd.set_option('display.max_columns',100)
train_data = pd.read_csv('train.csv')

# %%
train_data.shape
# Out:
# (1460, 81)

# %%
nan_cols = []
threshold = 50

for i in train_data.columns:
    if train_data[i].isna().sum()/len(train_data)*100 > threshold:
        nan_cols.append(i)
        
nan_cols
# Out:
# ['Alley', 'PoolQC', 'Fence', 'MiscFeature']

# %%
train_data.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# Alley             object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
# BsmtQual          object
# BsmtCond          object
# BsmtExposure      object
# BsmtFinType1      object
# BsmtFinSF1         int64
# BsmtFinType2      object
# BsmtFinSF2         int64
# ...

# %%
train_data.drop(nan_cols,axis = 1,inplace=True)

# %%
train_data.shape
# Out:
# (1460, 77)

# %%
num_data = train_data.select_dtypes(include='number')
cat_data = train_data.select_dtypes(include='object')

# %%
num_nan = []

for i in num_data.columns:
    if num_data[i].isna().sum() > 0:
        num_nan.append(i)
        
num_nan
# Out:
# ['LotFrontage', 'MasVnrArea', 'GarageYrBlt']

# %%
sns.boxplot(train_data['LotFrontage'])
# Out:
# C:\Users\Satyaki\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='LotFrontage'>

# %%
sns.boxplot(train_data['MasVnrArea'])
# Out:
# C:\Users\Satyaki\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='MasVnrArea'>

# %%
sns.boxplot(train_data['GarageYrBlt'])
# Out:
# C:\Users\Satyaki\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='GarageYrBlt'>

# %%
cat_nan = []

for i in cat_data.columns:
    if cat_data[i].isna().sum() > 0:
        cat_nan.append(i)
        
cat_nan
# Out:
# ['MasVnrType',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Electrical',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond']

# %%
len(cat_nan)
# Out:
# 12

# %%
mode = cat_nan
mean = []

for i in num_nan:
    if num_nan.index(i) == 2:
        mean.append(i)
    else:
        mode.append(i)
        
print('mode',len(mode))

print('mean',len(mean))
# Out:
# mode 14
# mean 1

# %%
mean
# Out:
# ['GarageYrBlt']

# %%
for i in mean:
    train_data[i] = train_data[i].fillna(train_data[i].mean())
    
for x in mode:
    train_data[x] = train_data[x].fillna(train_data[x].mode()[0])

# %%
train_data.isna().sum().sum()
# Out:
# 0

# %%
train_data.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
# BsmtQual          object
# BsmtCond          object
# BsmtExposure      object
# BsmtFinType1      object
# BsmtFinSF1         int64
# BsmtFinType2      object
# BsmtFinSF2         int64
# BsmtUnfSF          int64
# ...

# %%
train_data['Id'] = train_data['Id'].astype(object)

# %%
train_data.corr()
# Out:
#                MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  \
# MSSubClass       1.000000    -0.349116 -0.139781     0.032628    -0.059316
# LotFrontage     -0.349116     1.000000  0.281283     0.236891    -0.056461
# LotArea         -0.139781     0.281283  1.000000     0.105806    -0.005636
# OverallQual      0.032628     0.236891  0.105806     1.000000    -0.091932
# OverallCond     -0.059316    -0.056461 -0.005636    -0.091932     1.000000
# YearBuilt        0.027850     0.107427  0.014228     0.572323    -0.375983
# YearRemodAdd     0.040581     0.087325  0.013788     0.550684     0.073741
# MasVnrArea       0.023573     0.174146  0.103321     0.407252    -0.125694
# BsmtFinSF1      -0.069836     0.199171  0.214103     0.239666    -0.046231
# BsmtFinSF2      -0.065649     0.034498  0.111170    -0.059119     0.040229
# BsmtUnfSF       -0.140759     0.138852 -0.002618     0.308159    -0.136841
# ...

# %%
sns.heatmap(train_data.corr(),annot=False)
# Out:
# <AxesSubplot:>

# %%
sns.regplot(x='GrLivArea',y='SalePrice',data=train_data,line_kws={'color':'red'},scatter_kws={'color':'indigo'},marker='*')
# Out:
# <AxesSubplot:xlabel='GrLivArea', ylabel='SalePrice'>

# %%
sns.distplot(train_data['SalePrice'])
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='Density'>

# %%
sns.displot(train_data,y='SalePrice',hue='MSZoning',kind='hist')

# %%
cnt = 0
unique = []

for i in train_data['MSZoning']:
    if i not in unique:
        unique.append(i)
        cnt += 1
        
print('Unique Values :',unique)
print('Count :',cnt)
# Out:
# Unique Values : ['RL', 'RM', 'C (all)', 'FV', 'RH']
# Count : 5

# %%
train_data.head()
# Out:
#   Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0  1          60       RL         65.0     8450   Pave      Reg         Lvl
# 1  2          20       RL         80.0     9600   Pave      Reg         Lvl
# 2  3          60       RL         68.0    11250   Pave      IR1         Lvl
# 3  4          70       RL         60.0     9550   Pave      IR1         Lvl
# 4  5          60       RL         84.0    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 0    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 1    AllPub       FR2       Gtl      Veenker      Feedr       Norm     1Fam
# 2    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 3    AllPub    Corner       Gtl      Crawfor       Norm       Norm     1Fam
# 4    AllPub       FR2       Gtl      NoRidge       Norm       Norm     1Fam
#
# ...

# %%
sns.histplot(data=train_data,x='Street',y='SalePrice',hue='LotShape')
# Out:
# <AxesSubplot:xlabel='Street', ylabel='SalePrice'>
